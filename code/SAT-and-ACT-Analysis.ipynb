# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The ACT has been gaining popularity over the years and had surpassed the SAT in participation rate in the United States in 2012 and was winning state contracts. To address the declining market share, the College Board designed a new format for SAT which was released in March 2016. This report seeks to examine trends in the SAT and ACT participation rates and scores from 2017 to 2018 to uncover insights that could help to suggest a suitable state in which to focus the College Board's resources to improve SAT participate rate.

# %% [markdown]
# ## Executive Summary
#
# Participation rates for SAT and ACT are highly influenced by the state policies on college admissions. In general, states with high participation rates for either tests tend to have low participation rates for the other, which is especially true for states which adopt mandatory testing for one of the tests as seen in Illinois and Colorado which replaced mandatory ACT with SAT recently. As such, efforts to increase participation rates for SAT should be targeted to those states which do not have mandatory requirement for ACT.
#
# The SAT scores and highest/ lowest scoring states remained largely similar between 2017 and 2018, with addition of more states adopting mandatory SAT requirement. Test scores tend to be lower in states which adopt mandatory testing for either tests, compared to voluntary states.
#
# Based on the analysis, efforts to increase participation rates for SAT should be targeted towards California state where ACT is currently not mandatory. SAT is also a more popular choice compared to ACT for most districts within California hence there would be better chances of success in convincing the colleges to adopt SAT as the testing standard. In addtion, there is a high student population base thus resources could be allocated more efficiently to maximise pay-offs in increasing participation rate.
#
# Possible suggestions the College Board could adopt to increase SAT participation rate include fully subsidising SAT fees, making preparatory resources readily available and combining with free tutoring classes which have added advantage to raise test scores.
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
# The datasets contain the SAT/ ACT participation rates, individual mean subtest and total scores for individual states in the United States. The dataset appears to be complete as there are no null values. There is an extra entry in the ACT dataset for the national level participation rate and test scores, compared to the SAT dataset.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Yes, there are no null values.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
#
# Minimum score of 52 for Math subtest from SAT dataset seems very low compared to the other subtests; outside boundaries of 3x standard deviation from mean.
#
# Minimum score of 2.3 for Science subtest from ACT dataset seems very low compared to the other subtests; outside boundaries of 3x standard deviation from mean.
#
# SAT score: Minimum possible of 400; minimum possible of 200 for each subtest. Maximum possible of 1600; maximum of 800 for each subtest.
#
# ACT score: Minimum possible of 1 for each subtest/ overall composite. Maximum possible of 36 for each subtest/ overall composite.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# Check row entry for the low minimum Math score for SAT dataset
sat_2017[sat_2017['Math']==52]
# Fix incorrect Math subtest score from SAT dataset for Maryland State
sat_2017['Math'].replace(52,524, inplace = True)
# Check row entry for the low minimum Science score for ACT dataset
act_2017[act_2017['Science']==2.3]
# Fix incorrect Science subtest score from ACT dataset for Maryland State
act_2017['Science'].replace(2.3,23.2, inplace = True)

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
#
# For SAT dataset, the Participation feature should be in int64 data type.\
# For ACT dataset, the Participation feature should be in int64 data type and the Composite feature should be in float64 data type.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
def change_participation_data_type(data):
    data['Participation'] = data['Participation'].map(lambda x: x.strip("%"))
    data['Participation'] = data['Participation'].apply(pd.to_numeric)
    return data

# %%
change_participation_data_type(sat_2017)
# Out:
#                    State  Participation  Evidence-Based Reading and Writing  \
# 0                Alabama              5                                 593
# 1                 Alaska             38                                 547
# 2                Arizona             30                                 563
# 3               Arkansas              3                                 614
# 4             California             53                                 531
# 5               Colorado             11                                 606
# 6            Connecticut            100                                 530
# 7               Delaware            100                                 503
# 8   District of Columbia            100                                 482
# 9                Florida             83                                 520
# 10               Georgia             61                                 535
# ...

# %%
change_participation_data_type(act_2017)
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 0               National             60     20.3  20.7     21.4     21.0
# 1                Alabama            100     18.9  18.4     19.7     19.4
# 2                 Alaska             65     18.7  19.8     20.4     19.9
# 3                Arizona             62     18.6  19.8     20.1     19.8
# 4               Arkansas            100     18.9  19.0     19.7     19.5
# 5             California             31     22.5  22.7     23.1     22.2
# 6               Colorado            100     20.1  20.3     21.2     20.9
# 7            Connecticut             31     25.5  24.6     25.6     24.6
# 8               Delaware             18     24.1  23.4     24.8     23.6
# 9   District of Columbia             32     24.4  23.5     24.9     23.5
# 10               Florida             73     19.0  19.4     21.0     19.4
# 11               Georgia             55     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# Fix incorrect value for one of the composite scores which causes the data type to be reflected as an object
act_2017['Composite'].replace('20.2x',20.2, inplace = True)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# Convert participation rates to numeric
act_2017['Composite'] = act_2017['Composite'].apply(pd.to_numeric)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     int64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat_2017.rename(columns={
    'State': 'state',
    'Participation': 'sat_participation_2017',
    'Evidence-Based Reading and Writing': 'sat_evidence_based_reading_writing_2017',
    'Math': 'sat_math_2017',
    'Total': 'sat_total_2017'
}, inplace=True)

# %%
act_2017.rename(columns={
    'State': 'state',
    'Participation': 'act_participation_2017',
    'English': 'act_english_2017',
    'Math': 'act_math_2017',
    'Reading': 'act_reading_2017',
    'Science': 'act_science_2017',
    'Composite': 'act_composite_2017'
}, inplace=True)

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|2017 ACT/ SAT|The state names of the 51 states in the United States of America|
# |sat_participation_2017|integer|2017 SAT|The participate rate of the SAT in 2017 for each State (units in percent, where 60 means 60%)|
# |sat_evidence_based_reading_writing_2017|integer|2017 SAT|The average score of the Evidence-Based-Reading and Writing sub-test for SAT in 2017 for each State|
# |sat_math_2017|integer|2017 SAT|The average score of the Math sub-test for SAT in 2017 for each State|
# |sat_total_2017|integer|2017 SAT|The total score of the SAT in 2017 for each State|
# |act_participation_2017|integer|2017 ACT|The participate rate of the ACT in 2017 for each State (units in percent, where 60 means 60%)|
# |act_english_2017|float|2017 ACT|The average score of the English sub-test for ACT in 2017 for each State|
# |act_math_2017|float|2017 ACT|The average score of the Math sub-test for ACT in 2017 for each State|
# |act_reading_2017|float|2017 ACT|The average score of the Reading sub-test for ACT in 2017 for each State|
# |act_science_2017|float|2017 ACT|The average score of the Science sub-test for ACT in 2017 for each State|
# |act_composite_2017|float|2017 ACT|The total composite score of the ACT in 2017 for each State|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# Drop National level data
act_2017.drop(0)
# Out:
#                    state  act_participation_2017  act_english_2017  \
# 1                Alabama                     100              18.9
# 2                 Alaska                      65              18.7
# 3                Arizona                      62              18.6
# 4               Arkansas                     100              18.9
# 5             California                      31              22.5
# 6               Colorado                     100              20.1
# 7            Connecticut                      31              25.5
# 8               Delaware                      18              24.1
# 9   District of Columbia                      32              24.4
# 10               Florida                      73              19.0
# 11               Georgia                      55              21.0
# 12                Hawaii                      90              17.8
# 13                 Idaho                      38              21.9
# ...

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
combined_2017 = pd.merge(sat_2017, act_2017, on=['state'])
combined_2017.head()
# Out:
#         state  sat_participation_2017  \
# 0     Alabama                       5
# 1      Alaska                      38
# 2     Arizona                      30
# 3    Arkansas                       3
# 4  California                      53
#
#    sat_evidence_based_reading_writing_2017  sat_math_2017  sat_total_2017  \
# 0                                      593            572            1165
# 1                                      547            533            1080
# 2                                      563            553            1116
# 3                                      614            594            1208
# 4                                      531            524            1055
#
#    act_participation_2017  act_english_2017  act_math_2017  act_reading_2017  \
# 0                     100              18.9           18.4              19.7
# 1                      65              18.7           19.8              20.4
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
combined_2017.to_csv('../data/combined_2017.csv', index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#Read in SAT and ACT data:
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')
act_2018_updated = pd.read_csv('../data/act_2018_updated.csv')

# %%
# Check descriptive statistics of 2018 SAT data for any abnormal value
sat_2018.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
# Check whether data types of SAT 2018 are correct
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# Convert participation rate to numeric data type
change_participation_data_type(sat_2018)
# Out:
#                    State  Participation  Evidence-Based Reading and Writing  \
# 0                Alabama              6                                 595
# 1                 Alaska             43                                 562
# 2                Arizona             29                                 577
# 3               Arkansas              5                                 592
# 4             California             60                                 540
# 5               Colorado            100                                 519
# 6            Connecticut            100                                 535
# 7               Delaware            100                                 505
# 8   District of Columbia             92                                 497
# 9                Florida             56                                 550
# 10               Georgia             70                                 542
# ...

# %%
# Check 2018 ACT data structure. Sub-tests scores are missing.  
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
# Check updated 2018 ACT data structure. Sub-test scores are available. 
# Will use this dataset to combine with 2017 dataset so that comparison across subtest scores could be made   
act_2018_updated.head()
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# ...

# %%
act_2018_updated.describe()
# Out:
#        Percentage of Students Tested  Average Composite Score  \
# count                      51.000000                51.000000
# mean                       61.647059                21.486275
# std                        34.080976                 2.106278
# min                         7.000000                17.700000
# 25%                        28.500000                19.950000
# 50%                        66.000000                21.300000
# 75%                       100.000000                23.550000
# max                       100.000000                25.600000
#
#        Average English Score  Average Math Score  Average Reading Score  \
# count              51.000000           51.000000              51.000000
# mean               20.988235           21.125490              22.015686
# std                 2.446356            2.035765               2.167245
# min                16.600000           17.800000              18.000000
# ...

# %%
# Check data types of columns
act_2018_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          51 non-null     object
#  1   Percentage of Students Tested  51 non-null     int64
#  2   Average Composite Score        51 non-null     float64
#  3   Average English Score          51 non-null     float64
#  4   Average Math Score             51 non-null     float64
#  5   Average Reading Score          51 non-null     float64
#  6   Average Science Score          51 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
# Sort to compare against online source data 
act_2018_updated.sort_values(by=['Percentage of Students Tested','State'], ascending= (False, True))
# Out:
#                    State  Percentage of Students Tested  \
# 0                Alabama                            100
# 3               Arkansas                            100
# 17              Kentucky                            100
# 18             Louisiana                            100
# 24           Mississippi                            100
# 25              Missouri                            100
# 26               Montana                            100
# 27              Nebraska                            100
# 28                Nevada                            100
# 33        North Carolina                            100
# 35                  Ohio                            100
# 36              Oklahoma                            100
# 40        South Carolina                            100
# 42             Tennessee                            100
# 44                  Utah                            100
# 49             Wisconsin                            100
# ...

# %%
# Fix incorrect Composite score for Delaware state
act_2018_updated.loc[act_2018_updated['State']=='Delaware','Average Composite Score'] = 23.8

# %%
# Rename columns for sat_2018 data
sat_2018.rename(columns={
    'State': 'state',
    'Participation': 'sat_participation_2018',
    'Evidence-Based Reading and Writing': 'sat_evidence_based_reading_writing_2018',
    'Math': 'sat_math_2018',
    'Total': 'sat_total_2018'
}, inplace=True)

# %%
# Rename columns for act_2018_updated data
act_2018_updated.rename(columns={
    'State': 'state',
    'Percentage of Students Tested': 'act_participation_2018',
    'Average English Score': 'act_english_2018',
    'Average Math Score': 'act_math_2018',
    'Average Reading Score': 'act_reading_2018',
    'Average Science Score': 'act_science_2018',
    'Average Composite Score': 'act_composite_2018'
}, inplace=True)

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# Join 2018 SAT and ACT scores dataframes
combined_2018 = pd.merge(sat_2018, act_2018_updated, on=['state'])
combined_2018.head()
# Out:
#         state  sat_participation_2018  \
# 0     Alabama                       6
# 1      Alaska                      43
# 2     Arizona                      29
# 3    Arkansas                       5
# 4  California                      60
#
#    sat_evidence_based_reading_writing_2018  sat_math_2018  sat_total_2018  \
# 0                                      595            571            1166
# 1                                      562            544            1106
# 2                                      577            572            1149
# 3                                      592            576            1169
# 4                                      540            536            1076
#
#    act_participation_2018  act_composite_2018  act_english_2018  \
# 0                     100                19.1              18.9
# 1                      33                20.8              19.8
# 2                      66                19.2              18.2
# ...

# %%
# Join 2017 and 2018 dataframes
final =  pd.merge(combined_2017, combined_2018, on=['state'])
final.head()
# Out:
#         state  sat_participation_2017  \
# 0     Alabama                       5
# 1      Alaska                      38
# 2     Arizona                      30
# 3    Arkansas                       3
# 4  California                      53
#
#    sat_evidence_based_reading_writing_2017  sat_math_2017  sat_total_2017  \
# 0                                      593            572            1165
# 1                                      547            533            1080
# 2                                      563            553            1116
# 3                                      614            594            1208
# 4                                      531            524            1055
#
#    act_participation_2017  act_english_2017  act_math_2017  act_reading_2017  \
# 0                     100              18.9           18.4              19.7
# 1                      65              18.7           19.8              20.4
# ...

# %%
# Check data types of columns for consistency
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   state                                    51 non-null     object
#  1   sat_participation_2017                   51 non-null     int64
#  2   sat_evidence_based_reading_writing_2017  51 non-null     int64
#  3   sat_math_2017                            51 non-null     int64
#  4   sat_total_2017                           51 non-null     int64
#  5   act_participation_2017                   51 non-null     int64
#  6   act_english_2017                         51 non-null     float64
#  7   act_math_2017                            51 non-null     float64
#  8   act_reading_2017                         51 non-null     float64
#  9   act_science_2017                         51 non-null     float64
# ...

# %%
# standardise all columns with number formats to float
final[final.columns.drop('state')] = final[final.columns.drop('state')].astype(float)
    
# Check data types
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   state                                    51 non-null     object
#  1   sat_participation_2017                   51 non-null     float64
#  2   sat_evidence_based_reading_writing_2017  51 non-null     float64
#  3   sat_math_2017                            51 non-null     float64
#  4   sat_total_2017                           51 non-null     float64
#  5   act_participation_2017                   51 non-null     float64
#  6   act_english_2017                         51 non-null     float64
#  7   act_math_2017                            51 non-null     float64
#  8   act_reading_2017                         51 non-null     float64
#  9   act_science_2017                         51 non-null     float64
# ...

# %%
# Save out merged 2017 and 2018 dataset
final.to_csv('../data/final.csv', index=False)

# %% [markdown]
# #### Update data dictionary with 2018 data

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT/ SAT|The state names of the 51 states in the United States of America|
# |sat_participation_2017|float|2017 SAT|The participate rate of the SAT in 2017 for each State (units in percent, where 60 means 60%)|
# |sat_evidence_based_reading_writing_2017|float|2017 SAT|The average score of the Evidence-Based-Reading and Writing sub-test for SAT in 2017 for each State|
# |sat_math_2017|float|2017 SAT|The average score of the Math sub-test for SAT in 2017 for each State|
# |sat_total_2017|float|2017 SAT|The total score of the SAT in 2017 for each State|
# |act_participation_2017|float|2017 ACT|The participate rate of the ACT in 2017 for each State (units in percent, where 60 means 60%)|
# |act_english_2017|float|2017 ACT|The average score of the English sub-test for ACT in 2017 for each State|
# |act_math_2017|float|2017 ACT|The average score of the Math sub-test for ACT in 2017 for each State|
# |act_reading_2017|float|2017 ACT|The average score of the Reading sub-test for ACT in 2017 for each State|
# |act_science_2017|float|2017 ACT|The average score of the Science sub-test for ACT in 2017 for each State|
# |act_composite_2017|float|2017 ACT|The total composite score of the ACT in 2017 for each State|
# |sat_participation_2018|float|2018 SAT|The participate rate of the SAT in 2018 for each State (units in percent, where 60 means 60%)|
# |sat_evidence_based_reading_writing_2018|float|2018 SAT|The average score of the Evidence-Based-Reading and Writing sub-test for SAT in 2018 for each State|
# |sat_math_2018|float|2018 SAT|The average score of the Math sub-test for SAT in 2018 for each State|
# |sat_total_2017|float|2018 SAT|The total score of the SAT in 2018 for each State|
# |act_participation_2018|float|2018 ACT|The participate rate of the ACT in 2018 for each State (units in percent, where 60 means 60%)|
# |act_english_2018|float|2018 ACT|The average score of the English sub-test for ACT in 2018 for each State|
# |act_math_2018|float|2018 ACT|The average score of the Math sub-test for ACT in 2018 for each State|
# |act_reading_2018|float|2018 ACT|The average score of the Reading sub-test for ACT in 2018 for each State|
# |act_science_2018|float|2018 ACT|The average score of the Science sub-test for ACT in 2018 for each State|
# |act_composite_2018|float|2018 ACT|The total composite score of the ACT in 2018 for each State|

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final.describe().transpose()
# Out:
#                                          count         mean        std    min  \
# sat_participation_2017                    51.0    39.803922  35.276632    2.0
# sat_evidence_based_reading_writing_2017   51.0   569.117647  45.666901  482.0
# sat_math_2017                             51.0   556.882353  47.121395  468.0
# sat_total_2017                            51.0  1126.098039  92.494812  950.0
# act_participation_2017                    51.0    65.254902  32.140842    8.0
# act_english_2017                          51.0    20.931373   2.353677   16.3
# act_math_2017                             51.0    21.182353   1.981989   18.0
# act_reading_2017                          51.0    22.013725   2.067271   18.1
# act_science_2017                          51.0    21.450980   1.739353   18.2
# act_composite_2017                        51.0    21.519608   2.020695   17.8
# sat_participation_2018                    51.0    45.745098  37.314256    2.0
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def sd(data_list):
    mean = np.mean(data_list)
    n = len(data_list)
    
    sum_list = [(x - mean)**2 for x in data_list]

    return np.sqrt(np.sum(sum_list)/(n))

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
{final[col].name:sd(final[col]) for col in final.columns.drop('state')}
# Out:
# {'sat_participation_2017': 34.929070766645076,
#  'sat_evidence_based_reading_writing_2017': 45.21697020437866,
#  'sat_math_2017': 46.65713364485504,
#  'sat_total_2017': 91.58351056778743,
#  'act_participation_2017': 31.824175751231806,
#  'act_english_2017': 2.3304876369363368,
#  'act_math_2017': 1.9624620273436781,
#  'act_reading_2017': 2.046902931484265,
#  'act_science_2017': 1.7222161451443672,
#  'act_composite_2017': 2.0007860815819893,
#  'sat_participation_2018': 36.946619223539415,
#  'sat_evidence_based_reading_writing_2018': 47.03460978357609,
#  'sat_math_2018': 47.301945503783536,
#  'sat_total_2018': 93.22742384464432,
#  'act_participation_2018': 33.745194881997506,
#  'act_composite_2018': 2.0968220768561987,
#  'act_english_2018': 2.4222536143202795,
#  'act_math_2018': 2.0157072555557174,
#  'act_reading_2018': 2.1458918845104216,
#  'act_science_2018': 1.8516885484833538}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer:
# The manually calculated standard deviations is lower than the output from pandas `describe` as the `describe` function calculates the sample deviation using $(n-1)$ instead of $n$. However, it matches against numpy's `std`method.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# Filter states with 100% participation rate for 2017 SAT
final[['state','sat_participation_2017']][final['sat_participation_2017']==100]
# Out:
#                    state  sat_participation_2017
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 8   District of Columbia                   100.0
# 22              Michigan                   100.0

# %%
# Filter bottom 5 states with lowest participation rate for 2017 SAT
final[['state','sat_participation_2017']].sort_values(by=['sat_participation_2017'], ascending= (True)).head()
# Out:
#            state  sat_participation_2017
# 34  North Dakota                     2.0
# 24   Mississippi                     2.0
# 15          Iowa                     2.0
# 25      Missouri                     3.0
# 44          Utah                     3.0

# %%
# Filter states with 100% participation rate for 2018 SAT
final[['state','sat_participation_2018']][final['sat_participation_2018']==100]
# Out:
#           state  sat_participation_2018
# 5      Colorado                   100.0
# 6   Connecticut                   100.0
# 7      Delaware                   100.0
# 12        Idaho                   100.0
# 22     Michigan                   100.0

# %%
# Filter District of Columbia participation rate for SAT to check rate change compared to 100% in 2017 
final[['state','sat_participation_2018']][final['state']=='District of Columbia']
# Out:
#                   state  sat_participation_2018
# 8  District of Columbia                    92.0

# %%
# Filter bottom 5 states with lowest participation rate for 2018 SAT
final[['state','sat_participation_2018']].sort_values(by=['sat_participation_2018'], ascending= (True)).head()
# Out:
#            state  sat_participation_2018
# 34  North Dakota                     2.0
# 50       Wyoming                     3.0
# 41  South Dakota                     3.0
# 27      Nebraska                     3.0
# 49     Wisconsin                     3.0

# %% [markdown]
# #### SAT participation rates
# For the SAT in 2017, four states (Connecticut, Delaware, District of Columbia and Michigan) had 100% participation rate. The states having a 100% participation rate experienced a change in 2018, with addition of Colorado and Idaho, while Distict of Columbia dropped out of the list with participation rate dropping to 92%.
#
# The states with the lowest participation rates for the SAT in 2017 include Iowa, Mississippi, and North Dakota (all 2%). In 2018, North Dakota (2%), Wyoming, South Dakota, Nebraska and Wisconsin (all 3%) had the lowest participation rates.

# %%
# Filter states with 100% participation rate for 2017 ACT
final[['state','act_participation_2017']][final['act_participation_2017']==100]
# Out:
#              state  act_participation_2017
# 0          Alabama                   100.0
# 3         Arkansas                   100.0
# 5         Colorado                   100.0
# 17        Kentucky                   100.0
# 18       Louisiana                   100.0
# 23       Minnesota                   100.0
# 24     Mississippi                   100.0
# 25        Missouri                   100.0
# 26         Montana                   100.0
# 28          Nevada                   100.0
# 33  North Carolina                   100.0
# 36        Oklahoma                   100.0
# 40  South Carolina                   100.0
# 42       Tennessee                   100.0
# 44            Utah                   100.0
# 49       Wisconsin                   100.0
# 50         Wyoming                   100.0

# %%
# Filter bottom 5 states with lowest participation rate for 2017 ACT
final[['state','act_participation_2017']].sort_values(by=['act_participation_2017'], ascending= (True)).head()
# Out:
#             state  act_participation_2017
# 19          Maine                     8.0
# 29  New Hampshire                    18.0
# 7        Delaware                    18.0
# 39   Rhode Island                    21.0
# 38   Pennsylvania                    23.0

# %%
# Filter states with 100% participation rate for 2018 ACT
final[['state','act_participation_2018']][final['act_participation_2018']==100]
# Out:
#              state  act_participation_2018
# 0          Alabama                   100.0
# 3         Arkansas                   100.0
# 17        Kentucky                   100.0
# 18       Louisiana                   100.0
# 24     Mississippi                   100.0
# 25        Missouri                   100.0
# 26         Montana                   100.0
# 27        Nebraska                   100.0
# 28          Nevada                   100.0
# 33  North Carolina                   100.0
# 35            Ohio                   100.0
# 36        Oklahoma                   100.0
# 40  South Carolina                   100.0
# 42       Tennessee                   100.0
# 44            Utah                   100.0
# 49       Wisconsin                   100.0
# 50         Wyoming                   100.0

# %%
# Filter District of Colorado participation rate for ACT to check rate change compared to 100% in 2017 
final[['state','act_participation_2018']][final['state']=='Colorado']
# Out:
#       state  act_participation_2018
# 5  Colorado                    30.0

# %%
# Filter minnesota participation rate for ACT to check rate change compared to 100% in 2017
final[['state','act_participation_2018']][final['state']=='Minnesota']
# Out:
#         state  act_participation_2018
# 23  Minnesota                    99.0

# %%
# Filter bottom 5 states with lowest participation rate for 2018 ACT
final[['state','act_participation_2018']].sort_values(by=['act_participation_2018'], ascending= (True)).head()
# Out:
#             state  act_participation_2018
# 19          Maine                     7.0
# 39   Rhode Island                    15.0
# 29  New Hampshire                    16.0
# 7        Delaware                    17.0
# 38   Pennsylvania                    20.0

# %% [markdown]
# #### ACT participation rates
# For the ACT in 2017, 17 states had 100% participation rate. The states having a 100% participation rate experienced a change in 2018, with addition of Nebraska and Ohio, while Colorado (30%) and Minnesota (99%) dropped out of the list. The significant drop in ACT participation rate in Colorado is a result of the state ending mandatory ACT scores requirement for college admission.  https://www.daytondailynews.com/news/national-act-scores-for-class-2018-worst-decades-officials-say/EKA05C3FHcjN4bx8BmcC2N/
#
# The states with the lowest participation rates for the ACT in 2017 include Maine (8%), New Hampshire and Delaware (both 18%). In 2018, Maine (7%), Rhode Island (15%), and New Hampshire (16%) had the lowest ACT participation rates.

# %%
# Filter states with >50% participation rate for both tests in 2017
final[['state','sat_participation_2017','act_participation_2017']][(final['sat_participation_2017']>50) & (final['act_participation_2017']>50)]
# Out:
#       state  sat_participation_2017  act_participation_2017
# 9   Florida                    83.0                    73.0
# 10  Georgia                    61.0                    55.0
# 11   Hawaii                    55.0                    90.0

# %%
# Filter states with >50% participation rate for both tests in 2018
final[['state','sat_participation_2018','act_participation_2018']][(final['sat_participation_2018']>50) & (final['act_participation_2018']>50)]
# Out:
#              state  sat_participation_2018  act_participation_2018
# 9          Florida                    56.0                    66.0
# 10         Georgia                    70.0                    53.0
# 11          Hawaii                    56.0                    89.0
# 33  North Carolina                    52.0                   100.0
# 40  South Carolina                    55.0                   100.0

# %%
# Filter states with 100% participation rate for SAT in either 2017 or 2018 and compare to their respective ACT participation rates
final[['state','sat_participation_2017','act_participation_2017','sat_participation_2018','act_participation_2018']][(final['sat_participation_2017']==100) | (final['sat_participation_2018']==100)]
# Out:
#                    state  sat_participation_2017  act_participation_2017  \
# 5               Colorado                    11.0                   100.0
# 6            Connecticut                   100.0                    31.0
# 7               Delaware                   100.0                    18.0
# 8   District of Columbia                   100.0                    32.0
# 12                 Idaho                    93.0                    38.0
# 22              Michigan                   100.0                    29.0
#
#     sat_participation_2018  act_participation_2018
# 5                    100.0                    30.0
# 6                    100.0                    26.0
# 7                    100.0                    17.0
# 8                     92.0                    32.0
# 12                   100.0                    36.0
# 22                   100.0                    22.0

# %%
# Filter states with 100% participation rate for ACT in either 2017 or 2018 and compare to their respective SAT participation rates
final[['state','act_participation_2017','sat_participation_2017','act_participation_2018','sat_participation_2018']][(final['act_participation_2017']==100) | (final['act_participation_2018']==100)]
# Out:
#              state  act_participation_2017  sat_participation_2017  \
# 0          Alabama                   100.0                     5.0
# 3         Arkansas                   100.0                     3.0
# 5         Colorado                   100.0                    11.0
# 17        Kentucky                   100.0                     4.0
# 18       Louisiana                   100.0                     4.0
# 23       Minnesota                   100.0                     3.0
# 24     Mississippi                   100.0                     2.0
# 25        Missouri                   100.0                     3.0
# 26         Montana                   100.0                    10.0
# 27        Nebraska                    84.0                     3.0
# 28          Nevada                   100.0                    26.0
# 33  North Carolina                   100.0                    49.0
# 35            Ohio                    75.0                    12.0
# ...

# %% [markdown]
# #### Participation rates for both SAT and ACT
#
# In 2017, only three states (Florida, Georgia, and Hawaii) had above 50% participation rates for both tests. This list expanded in 2018 to include two additional states (North Carolina and South Carolina).The increase in SAT participation rate for these two states in 2018 was marginal with both having close to 50% participation rate in 2017, coupled with 100% ACT participation rate for both years.
#
# In general, there is an inverse relationship between SAT and ACT participation rates. States with high participation rates for SAT tend to have low participation rates for ACT, and vice versa. Among the states with 100% SAT participation rate, their respective ACT participation rates were generally low between 17 to 32%. Among the states with 100% ACT participation rate, their respective SAT participation rates were also generally low between 2 to 55%.
#
# It should be noted that most colleges and universities in the US accept scores from either the SAT or ACT. Hence, there is not much incentive for the students to take two tests. As such, efforts to increase participation rates for SAT should be targeted to those states which do not have mandatory requirement for ACT scores. (https://www.edweek.org/ew/section/multimedia/states-require-students-take-sat-or-act.html)

# %%
# Filter top 5 states with highest mean total score for 2017 SAT
final[['state','sat_total_2017']].sort_values(by=['sat_total_2017'], ascending= (False)).head()
# Out:
#         state  sat_total_2017
# 23  Minnesota          1295.0
# 49  Wisconsin          1291.0
# 15       Iowa          1275.0
# 25   Missouri          1271.0
# 16     Kansas          1260.0

# %%
# Filter bottom 5 states with lowest mean total score for 2017 SAT
final[['state','sat_total_2017']].sort_values(by=['sat_total_2017'], ascending= (True)).head()
# Out:
#                    state  sat_total_2017
# 8   District of Columbia           950.0
# 7               Delaware           996.0
# 12                 Idaho          1005.0
# 22              Michigan          1005.0
# 19                 Maine          1012.0

# %%
# Filter top 5 states with highest mean total score for 2018 SAT
final[['state','sat_total_2018']].sort_values(by=['sat_total_2018'], ascending= (False)).head()
# Out:
#            state  sat_total_2018
# 23     Minnesota          1298.0
# 49     Wisconsin          1294.0
# 34  North Dakota          1283.0
# 15          Iowa          1265.0
# 16        Kansas          1265.0

# %%
# Filter bottom 5 states with lowest mean total score for 2018 SAT
final[['state','sat_total_2018']].sort_values(by=['sat_total_2018'], ascending= (True)).head()
# Out:
#                    state  sat_total_2018
# 8   District of Columbia           977.0
# 7               Delaware           998.0
# 48         West Virginia           999.0
# 12                 Idaho          1001.0
# 44                  Utah          1010.0

# %% [markdown]
# #### SAT mean total scores
#
# In general, the highest and lowest scoring states remain similar across 2017 and 2018. The three states with the highest SAT scores in 2017 were Minnesota (1295), Wisconsin (1291), and Iowa (1275) while the lowest scoring states were District of Columbia (950), Delaware (996), and Michigan (1005). In 2018, the highest scoring states were Minnesota (1298), Wisconsin (1294), and North Dakota (1283), while the lowest scoring states were District of Columbia (977), Delaware (998), and West Virginia (999).
#
# The highest scoring states tend to have low participation rates, and vice versa. For example, Iowa and Wisconsin are among the highest scoring states but has the lowest participation rates in 2017 and 2018 respectively, whereas the lowest scoring states in 2017 (District of Columbia, Delaware, and Michigan) and 2018 (Delaware and Idaho) all had 100% participation rates.

# %%
# Filter top 5 states with highest average composite score for 2017 ACT
final[['state','act_composite_2017']].sort_values(by=['act_composite_2017'], ascending= (False)).head()
# Out:
#                    state  act_composite_2017
# 29         New Hampshire                25.5
# 21         Massachusetts                25.4
# 6            Connecticut                25.2
# 19                 Maine                24.3
# 8   District of Columbia                24.2

# %%
# Filter bottom 5 states with lowest average composite score for 2017 ACT
final[['state','act_composite_2017']].sort_values(by=['act_composite_2017'], ascending= (True)).head()
# Out:
#              state  act_composite_2017
# 28          Nevada                17.8
# 24     Mississippi                18.6
# 40  South Carolina                18.7
# 11          Hawaii                19.0
# 33  North Carolina                19.1

# %%
# Filter top 5 states with highest average composite score for 2018 ACT
final[['state','act_composite_2018']].sort_values(by=['act_composite_2018'], ascending= (False)).head()
# Out:
#             state  act_composite_2018
# 6     Connecticut                25.6
# 21  Massachusetts                25.5
# 29  New Hampshire                25.1
# 32       New York                24.5
# 22       Michigan                24.4

# %%
# Filter bottom 5 states with lowest average composite score for 2018 ACT
final[['state','act_composite_2018']].sort_values(by=['act_composite_2018'], ascending= (True)).head()
# Out:
#              state  act_composite_2018
# 28          Nevada                17.7
# 40  South Carolina                18.3
# 24     Mississippi                18.6
# 11          Hawaii                18.9
# 0          Alabama                19.1

# %% [markdown]
# #### ACT average composite scores
#
# In general, the highest and lowest scoring states remain similar across 2017 and 2018, and observed similar inverse relationship trending with respect to participation rates. The three states with the highest ACT scores in 2017 were New Hampshire (25.5), Massachusetts (25.4), and Connecticut (25.2), while the lowest scoring states were Nevada (17.8), Mississippi (18.6), and South Carolina (18.7). In 2018, the highest scoring states were Connecticut (25.6), Massachusetts (25.5), and New Hampshire (25.1), while the lowest scoring states were Nevada (17.7), South Carolina (18.3), and Mississippi (18.6).

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
fig, ax = plt.subplots(figsize=(16, 12))

sns.heatmap(final.corr(),linewidths=0.1,annot=True)
ax.set_title("Correlation Heatmap",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# The correlation heatmap above show that the trends are generally similar from 2017 to 2018.
#
# Strong negative correlations (r between -0.8 - 0.9) can be seen between:
#
# - Participation rates for SAT/ ACT, and their total/ composite scores
# - Participation rate for SAT, and participation rate for ACT
#
# whereas strong positive correlations (r between 0.8 to 1.0) can be seen between:
#
# - scores for each subtest, and their total/ composite scores for both SAT and ACT
# - scores in 2017, and scores in 2018
#
# There is however a weak negative correlation ( r between -0.4 to -0.5) between math/reading & writing/ total scores for SAT, and respective math/ reading/ composite scores for ACT.

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(12, nrows+6), sharey=True) 
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], bins=15)
        ax[i].set_title(list_of_titles[i],fontsize=16)
        ax[i].set_xlabel(list_of_xlabels[i],fontsize=14)
        ax[i].set_ylabel(list_of_ylabels[i],fontsize=14)
      
    plt.tight_layout()

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Histograms of Participation rates for SAT & ACT
participation = ['sat_participation_2017','sat_participation_2018','act_participation_2017','act_participation_2018']
titles = ['Histogram of SAT Participation Rate (2017)','Histogram of SAT Participation Rate (2018)','Histogram of ACT Participation Rate (2017)','Histogram of ACT Participation Rate (2018)']
x_labels = ['','','Participation rate (%)','Participation rate (%)' ]  
y_labels = ['Number of States','','Number of States','' ]  
subplot_histograms(final,participation,titles,x_labels,y_labels)

# %% [markdown]
# #### Participation rates for SAT & ACT
# The distributions of participation rates for both SAT and ACT do not follow a normal distribution. For SAT, there is a large group of states at the lower end of participation rates (< 10%), as compared to ACT where there is a large group of states at the higher end of participation rates (> 90%) with almost no states with participation rates of < 10%.

# %%
# Histograms of Math scores for SAT & ACT
math = ['sat_math_2017','sat_math_2018','act_math_2017','act_math_2018']
titles = ['Histogram of SAT Math Score (2017)','Histogram of SAT Math Score (2018)','Histogram of ACT Math Score (2017)','Histogram of ACT Math Score (2018)']
x_labels = ['','','Math Score','Math Score' ]  
y_labels = ['Number of States','','Number of States','' ]  
subplot_histograms(final,math,titles,x_labels,y_labels)

# %% [markdown]
# #### Math scores for SAT & ACT
# The distribution of math scores for both SAT and ACT are similar and appear to be bimodal with a bigger peak at the lower spectrum of scores and a smaller peak at the higher score spectrum, suggesting there is a cluster of states with high math scores and a cluster with low maths scores.

# %%
# Histograms of Reading/verbal scores for SAT & ACT
reading = ['sat_evidence_based_reading_writing_2017','sat_evidence_based_reading_writing_2018','act_reading_2017','act_reading_2018']
titles = ['Histogram of SAT Reading & Writing Score (2017)','Histogram of SAT Reading & Writing Score (2018)','Histogram of ACT Reading Score (2017)','Histogram of ACT Reading Score (2018)']
x_labels = ['','','Score','Score' ]  
y_labels = ['Number of States','','Number of States','' ]  
subplot_histograms(final,reading,titles,x_labels,y_labels)

# %% [markdown]
# #### Reading/Verbal scores for SAT & ACT
# The distribution of reading scores for both SAT and ACT are similar and appear to be bimodal, similar to the math scores.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Custom function to plot scatterplots
def scatterplot(dataframe, col1, col2, title,color=None):
    sns.regplot(dataframe[col1],dataframe[col2],
                scatter_kws={'facecolors':color,'edgecolor':color},)
    plt.title(title,fontsize=14)
    plt.xlabel(col1,fontsize=12)
    plt.ylabel(col2,fontsize=12)

# %%
plt.figure(figsize=(15,4))

# Scatterplot of SAT vs. ACT math scores for 2017
plt.subplot(1,3,1)
scatterplot(final,'sat_math_2017','act_math_2017','SAT vs. ACT math scores (2017)')
# Scatterplot of  SAT vs. ACT math scores for 2018
plt.subplot(1,3,2)
scatterplot(final,'sat_evidence_based_reading_writing_2017','act_reading_2017','SAT vs. ACT verbal/ reading scores (2017)')
# Scatterplot of SAT vs. ACT total/composite scores for 2017
plt.subplot(1,3,3)
scatterplot(final,'sat_total_2017','act_composite_2017','SAT vs. ACT total/composite scores (2017)')

plt.tight_layout()

# %% [markdown]
# #### SAT vs. ACT subject and total scores
# There is a weak negative correlation (shown by the more spreadout scatter plots around the trend line) between SAT subject/ total scores, and respective subject/ composite scores for ACT.

# %%
plt.figure(figsize=(10,4))

# Scatterplot of SAT total scores (2017) vs SAT total scores (2018)
plt.subplot(1,2,1)
scatterplot(final,'sat_total_2017','sat_total_2018','Total scores for SAT (2017) vs SAT (2018)')
# Scatterplot of ACT composite scores (2017) vs ACT composite scores (2018)
plt.subplot(1,2,2)
scatterplot(final,'act_composite_2017','act_composite_2018','Composite scores for ACT (2017) vs ACT (2018)')

plt.tight_layout()

# %% [markdown]
# #### SAT total/ ACT composite (2017) vs. SAT total/ ACT composite (2018)
# There is a strong positive correlation (shown by the more clustered scatter plots around the trend line) between SAT total/ ACT composite scores in 2017 and scores in 2018.

# %%
plt.figure(figsize=(10,4))

# Scatterplot of SAT participation rate (2017) vs ACT participation rate (2017)
plt.subplot(1,2,1)
scatterplot(final,'sat_participation_2017','act_participation_2017','SAT vs. ACT Participation Rates (2017)')
# Scatterplot of SAT participation rate (2018) vs ACT participation rate (2018)
plt.subplot(1,2,2)
scatterplot(final,'sat_participation_2018','act_participation_2018','SAT vs. ACT Participation Rates (2018)')

plt.tight_layout()

# %% [markdown]
# #### SAT vs. ACT participation rates
# There is a strong negative correlation between SAT and ACT participation rates.

# %%
plt.figure(figsize=(10,4))

# Scatterplot of SAT participation rate (2017) vs SAT scores (2017)
plt.subplot(1,2,1)
scatterplot(final,'sat_participation_2017','sat_total_2017','SAT Participation vs. SAT Scores (2017)')

# Scatterplot of SAT participation rate (2018) vs SAT scores (2018)
plt.subplot(1,2,2)
scatterplot(final,'sat_participation_2018','sat_total_2018','SAT Participation vs. SAT Scores (2018)')

plt.tight_layout()

# %% [markdown]
# #### SAT participation vs. SAT total scores
# There is a strong negative correlation between SAT participation rate and total scores. Efforts to increase SAT participation rates would likely result in lower mean test scores.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
sat_subject_scores = ['sat_evidence_based_reading_writing_2017','sat_evidence_based_reading_writing_2018','sat_math_2017','sat_math_2018']
sat_scores_total = ['sat_total_2017','sat_total_2018']
act_scores = ['act_english_2017','act_english_2018','act_math_2017','act_math_2018','act_reading_2017','act_reading_2018','act_science_2017','act_science_2018','act_composite_2017','act_composite_2018']
sat_act_participation_rate = ['sat_participation_2017','sat_participation_2018','act_participation_2017','act_participation_2018']

fig, ax = plt.subplots(2,2, figsize=(15, 10)) 

sns.boxplot(data=final[sat_subject_scores],ax = ax[0][0],orient='h')
ax[0][0].set_title('SAT subject scores (2017 and 2018)',fontsize=16)
plt.setp(ax[0][0].get_xticklabels(), fontsize=14)

sns.boxplot(data=final[sat_scores_total],ax = ax[0][1],orient='h')
ax[0][1].set_title('SAT total scores (2017 and 2018)',fontsize=16)
plt.setp(ax[0][1].get_xticklabels(), fontsize=14)

sns.boxplot(data=final[act_scores],ax = ax[1][0],orient='h')
ax[1][0].set_title('ACT scores (2017 and 2018)',fontsize=16)
plt.setp(ax[1][0].get_xticklabels(), fontsize=14)

sns.boxplot(data=final[sat_act_participation_rate],ax = ax[1][1],orient='h')
ax[1][1].set_title('ACT/SAT participation rates (2017 and 2018)',fontsize=16)
plt.setp(ax[1][1].get_xticklabels(), fontsize=14)

plt.tight_layout()

# %% [markdown]
# #### Test Scores
#
# The SAT and ACT scores distribution was largely similar between 2017 and 2018. Among the SAT subject scores, the math scores tend to score lower than reading/ writing scores reflected by the higher median scores. For the ACT subject scores, the reading test scores have a higher median while the english scores has a larger spread compared to the other subjects.
#
# #### Participation rates
#
# For the participation rates, ACT has a higher participation rate as compared to SAT across both years shown by the higher median. There was a narrower gap in 2018 with the increased participation rate for SAT due to more states institutionalising mandatory SAT tests.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### Participation rates in non-mandatory or non-funded states

# %% [markdown]
# From the above analysis, efforts to increase SAT participation rate should be targeted to those states which do not have mandatory or fully subsidised ACT /SAT testing for college admissions currently.
#
# Another consideration is the popularity of the SAT compared to the ACT among those states which administer voluntary tests, in terms of SAT: ACT participation rate ratio where efforts should be directed to those states with higher participation ratio for better chances of success in convincing the state to adopt SAT as the testing standard.

# %%
# Filter dictionary to identify those states with mandatory or fully subsidised tests
# https://www.testive.com/state-sat-act/
# https://www.usnews.com/education/best-colleges/articles/2018-01-23/how-to-take-the-sat-act-for-free

filter_dict = { 
    
    'required_act':[
        'Alabama','Hawaii','Kentucky','Louisiana',
        'Mississippi','Missouri','Montana','Nebraska',
        'Nevada','North Carolina','North Dakota','Ohio','South Carolina','Utah',
        'Wisconsin','Wyoming'
    ],
    
    'required_sat':[
        'Colorado','Connecticut','Delaware','District of Columbia',
        'Illinois','Maine','Michigan','New Hampshire','Ohio','Tennessee'
    ],

     'free_act':[
        'Alabama','Arkansas','Hawaii','Kansas','Kentucky',
        'Louisiana','Minnesota','Mississippi','Montana','Nebraska',
        'Nevada','North Carolina','North Dakota','Ohio','Oklahoma','South Carolina','Tennessee',
        'Utah','Wisconsin','Wyoming'
    ],
    'free_sat':[
        'Colorado','Connecticut','Delaware','District of Columbia','Idaho','Illinois',
        'Maine','Michigan','New Hampshire','Rhode Island','West Virginia']  
}

# %%
# Identify target states for further recommendation evaluation by filtering out those states with mandatory or fully subsidised tests 

target_states = [] 
for state in final.state:
    if (state not in filter_dict['required_act'])\
        &(state not in filter_dict['required_sat'])\
        &(state not in filter_dict['free_act'])\
        &(state not in filter_dict['free_sat']):
        target_states.append(state)
target_states
# Out:
# ['Alaska',
#  'Arizona',
#  'California',
#  'Florida',
#  'Georgia',
#  'Indiana',
#  'Iowa',
#  'Maryland',
#  'Massachusetts',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'Oregon',
#  'Pennsylvania',
#  'South Dakota',
#  'Texas',
#  'Vermont',
#  'Virginia',
#  'Washington']

# %%
# Derive SAT: ACT participation ratio
final['sat_act_ratio'] = final['sat_participation_2018'] / final['act_participation_2018'] 
# Sort by top 10 highest sat:act participation ratio
final[(final['state'].isin(target_states))][['state','sat_participation_2018','act_participation_2018','sat_act_ratio']].sort_values(['sat_act_ratio'],ascending=False).head(10)
# Out:
#             state  sat_participation_2018  act_participation_2018  \
# 38   Pennsylvania                    70.0                    20.0
# 21  Massachusetts                    80.0                    25.0
# 32       New York                    79.0                    27.0
# 47     Washington                    69.0                    24.0
# 46       Virginia                    68.0                    24.0
# 45        Vermont                    64.0                    24.0
# 30     New Jersey                    82.0                    31.0
# 20       Maryland                    76.0                    31.0
# 4      California                    60.0                    27.0
# 14        Indiana                    63.0                    32.0
#
#     sat_act_ratio
# 38       3.500000
# 21       3.200000
# 32       2.925926
# 47       2.875000
# 46       2.833333
# 45       2.666667
# 30       2.645161
# 20       2.451613
# 4        2.222222
# 14       1.968750

# %% [markdown]
# #### Student population for individual states

# %% [markdown]
# In addition, efforts to increase SAT participation rates should also be directed to states with high student population for better efficiency in resource allocation to maximise pay-offs.

# %%
#Read in SAT participants and graduate data extracted from additional data provided:
sat_participants = pd.read_csv('../data/sat_participants.csv')
sat_participants.head()
# Out:
#         state  sat17_participants  17_graduates  sat18_participants  \
# 0     Alabama                2393         49102                2878
# 1      Alaska                2971          7770                3334
# 2     Arizona               20466         67909               20188
# 3    Arkansas                1065         30904                1591
# 4  California              226699        425864              262228
#
#    18_graduates
# 0         49844
# 1          7796
# 2         68627
# 3         31126
# 4        435365

# %%
# Rename columns for sat_participants data
sat_participants.rename(columns={
    'sat17_participants': 'sat_participants_2017',
    'sat18_participants': 'sat_participants_2018',
    '17_graduates': 'graduates_2017',
    '18_graduates': 'graduates_2018'
}, inplace=True)

# %%
final = pd.merge(final, sat_participants, on=['state'])
final.head()
# Out:
#         state  sat_participation_2017  \
# 0     Alabama                     5.0
# 1      Alaska                    38.0
# 2     Arizona                    30.0
# 3    Arkansas                     3.0
# 4  California                    53.0
#
#    sat_evidence_based_reading_writing_2017  sat_math_2017  sat_total_2017  \
# 0                                    593.0          572.0          1165.0
# 1                                    547.0          533.0          1080.0
# 2                                    563.0          553.0          1116.0
# 3                                    614.0          594.0          1208.0
# 4                                    531.0          524.0          1055.0
#
#    act_participation_2017  act_english_2017  act_math_2017  act_reading_2017  \
# 0                   100.0              18.9           18.4              19.7
# 1                    65.0              18.7           19.8              20.4
# ...

# %%
# Derive student numbers who did not take SAT in 2018 for each state
final['non_tested_students_2018'] = final['graduates_2018'] - final['sat_participants_2018']

# %%
# Sort by top 10 non-SAT tested graduates
final[(final['state'].isin(target_states))][['state','sat_participation_2018','act_participation_2018','non_tested_students_2018','sat_act_ratio']].sort_values(['non_tested_students_2018'],ascending=False).head(10)
# Out:
#            state  sat_participation_2018  act_participation_2018  \
# 4     California                    60.0                    27.0
# 43         Texas                    66.0                    41.0
# 2        Arizona                    29.0                    66.0
# 32      New York                    79.0                    27.0
# 38  Pennsylvania                    70.0                    20.0
# 15          Iowa                     3.0                    68.0
# 10       Georgia                    70.0                    53.0
# 46      Virginia                    68.0                    24.0
# 14       Indiana                    63.0                    32.0
# 47    Washington                    69.0                    24.0
#
#     non_tested_students_2018  sat_act_ratio
# 4                     173137       2.222222
# 43                    115239       1.609756
# 2                      48439       0.439394
# 32                     44279       2.925926
# ...

# %%
# Scatterplot of evaluation matrix for targeted states

plt.figure(figsize=(12,8))

sns.scatterplot(x='non_tested_students_2018',y='sat_act_ratio',data=final[(final['state'].isin(target_states))],s=200)

plt.axvline(x=87500,color='black')
plt.axhline(y=1.75,color='black')
plt.title('Evaluation Matrix for Targeted States',fontsize=20)
plt.xlabel("Non-tested Student Population (2018)", size = 16)
plt.ylabel("SAT: ACT Participation Ratio", size = 16)
plt.xticks(size=14)
plt.yticks(size=14);

# %% [markdown]
# #### Targeted state
#
# Based on the selection matrix scatterplot above, the state which falls on the top right quadrant (selection criteria target) corresponds to **California**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:
#
# The distributions of participation rates and test scores for both SAT and ACT in 2017 and 2018 do not follow a normal distribution shown by the histograms above. Below is the summarised statistics from 51 states to describe the central tendency, spread, and shape/skewness of the distributions. A median which is higher or lower than the mean suggests a skewness in the distribution.
#
# #### SAT (2017)
#
# The participation rate for SAT had a mean of 39.8%, with a standard deviation of 35.3%. The minimum, 25th percentile, median, 75th percentile and maximum participation rate was at 0%, 4.0%, 38.0%, 66.0% and 100% respectively.
#
# The score for the Evidence-Based Reading and Writing sub-test had a mean of 569.1, with a standard deviation of 45.7. The minimum, 25th percentile, median, 75th percentile and maximum score was at 482.0, 533.5, 559.0, 613.0 and 644.0 respectively.
#
# The score for the Math sub-test had a mean of 556.9, with a standard deviation of 47.1. The minimum, 25th percentile, median, 75th percentile and maximum score was at 468.0, 523.5, 548.0, 599.0 and 651.0 respectively.
#
# The total score had a mean of 1126.1, with a standard deviation of 92.5. The minimum, 25th percentile, median, 75th percentile and maximum score was at 950.0, 1055.5, 1107.0, 1212.0 and 1295.0 respectively.
#
# #### SAT (2018)
#
# The participation rate for SAT had a mean of 45.7%, with a standard deviation of 37.3%. The minimum, 25th percentile, median, 75th percentile and maximum participation rate was at 2.0%, 4.5%, 52.0%, 77.5% and 100% respectively.
#
# The score for the Evidence-Based Reading and Writing sub-test had a mean of 563.7, with a standard deviation of 47.5. The minimum, 25th percentile, median, 75th percentile and maximum score was at 480.0, 534.5, 552.0, 610.5 and 643.0 respectively.
#
# The score for the Math sub-test had a mean of 556.2, with a standard deviation of 47.8. The minimum, 25th percentile, median, 75th percentile and maximum score was at 480.0, 522.5, 544.0, 593.5 and 655.0 respectively.
#
# The total score had a mean of 1120.0, with a standard deviation of 94.1. The minimum, 25th percentile, median, 75th percentile and maximum score was at 977.0, 1057.5, 1098.0, 1204.0 and 1298.0 respectively.
#
# #### ACT (2017)
#
# The participation rate for ACT had a mean of 65.3%, with a standard deviation of 32.1%. The minimum, 25th percentile, median, 75th percentile and maximum participation rate was at 8.0%, 31.0%, 69.0%, 100% and 100% respectively.
#
# The score for the English sub-test had a mean of 20.9, with a standard deviation of 2.4. The minimum, 25th percentile, median, 75th percentile and maximum score was at 16.3, 19.0, 20.7, 23.3 and 25.5 respectively.
#
# The score for the Math sub-test had a mean of 21.2, with a standard deviation of 2.0. The minimum, 25th percentile, median, 75th percentile and maximum score was at 18.0, 19.4, 20.9, 23.1 and 25.3 respectively.
#
# The score for the Reading sub-test had a mean of 22.0, with a standard deviation of 2.1. The minimum, 25th percentile, median, 75th percentile and maximum score was at 18.1, 20.5, 21.8, 24.1 and 26.0 respectively.
#
# The score for the Science sub-test had a mean of 21.5, with a standard deviation of 1.7. The minimum, 25th percentile, median, 75th percentile and maximum score was at 18.2, 20.0, 21.3, 23.2 and 24.9 respectively.
#
# The composite score had a mean of 21.5, with a standard deviation of 2.0. The minimum, 25th percentile, median, 75th percentile and maximum score was at 17.8, 19.8, 21.4, 23.6 and 25.5 respectively.
#
# #### ACT (2018)
#
# The participation rate for ACT had a mean of 61.6%, with a standard deviation of 34.1%. The minimum, 25th percentile, median, 75th percentile and maximum participation rate was at 7.0%, 28.5%, 66.0%, 100% and 100% respectively.
#
# The score for the English sub-test had a mean of 21.0, with a standard deviation of 2.4. The minimum, 25th percentile, median, 75th percentile and maximum score was at 16.6, 19.1, 20.2, 23.7 and 26.0 respectively.
#
# The score for the Math sub-test had a mean of 21.1, with a standard deviation of 2.0. The minimum, 25th percentile, median, 75th percentile and maximum score was at 17.8, 19.4, 20.7, 23.2 and 25.2 respectively.
#
# The score for the Reading sub-test had a mean of 22.0, with a standard deviation of 2.2. The minimum, 25th percentile, median, 75th percentile and maximum score was at 18.0, 20.5, 21.6, 24.1 and 26.1 respectively.
#
# The score for the Science sub-test had a mean of 21.3, with a standard deviation of 1.9. The minimum, 25th percentile, median, 75th percentile and maximum score was at 17.9, 19.9, 21.1, 23.1 and 24.9 respectively.
#
# The composite score had a mean of 21.5, with a standard deviation of 2.1. The minimum, 25th percentile, median, 75th percentile and maximum score was at 17.7, 20.0, 21.3, 23.7 and 25.6 respectively.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: No, we did not though there are some bimodal normal distribution observed on the test scores. This could be due to state level interventions e.g. mandatory test requirements for either SAT or ACT.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
#
# #### Math
#
# The distributions for Math scores appear to be bimodal, which could result in high margin of error in any estimates made.
#
# #### Reading
#
# The distributions for Reading scores appear to be bimodal, which could result in high margin of error in any estimates made.
#
# #### Rates
#
# The distributions for participation rates are not normal due to certain states with mandatory requirements for either tests as well as multiple states that have their own tests instead of using the standardised tests for college entry requirement.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
# No, the participation rates do not reflect the actual population taking the tests. Some states could have a low population size hence any change in population could have a great impact on the participation rate.
#
# Also, the participation rates could contain overlapping samples as some students could take both SAT and ACT tests hence would not make sense to use these data to conduct statistical inference.
#
# More data required at district and state level on the population will be required to be used as samples to conduct statistical inference.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
#
# It is not appropriate to compare SAT and ACT math scores as the scores have different scales and different test formats and emphasis e.g. there is a "no-calculator" subsection in SAT which does not apply in ACT. (https://blog.prepscholar.com/act-vs-sat)

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
# Tabulate difference in SAT and ACT participation rate 
final['sat_participation_diff'] = final['sat_participation_2018'] - final['sat_participation_2017'] 
final['act_participation_diff'] = final['act_participation_2018'] - final['act_participation_2017']

# %%
# Plot bar charts to visualise rate change
fig, ax = plt.subplots(1,2,figsize=(10, 10),sharey=True) 
plt.subplots_adjust(wspace=0.03)

# SAT participation rate change 
final = final.sort_values(by='sat_participation_diff',ascending=False)
sns.barplot(y='state', x='sat_participation_diff',data=final,color='skyblue',ax=ax[0])
ax[0].set_title('SAT Participation Rate Change over 2017-2018',fontsize=10)
ax[0].set_xlabel('Rate Change (%)')

# ACT participation rate change

sns.barplot(y='state', x='act_participation_diff',data=final,color='sandybrown',ax=ax[1])
ax[1].set_title('ACT Participation Rate Change over 2017-2018',fontsize=10)
ax[1].set_xlabel('Rate Change (%)')
ax[1].set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# The two states which show the biggest changes in SAT/ ACT participation rates from 2017 to 2018 were Illinois and Colorado shown by the bar chart above. There is also an interesting trend for Ohio which saw both SAT and ACT participation rates increasing from 2017 to 2018.
#
# #### Illinois
#
# There is a drastic jump in SAT participation rates of 90% (from 9% to 99%) from 2017 to 2018, with corresponding fall in ACT participation rates of 50% (from 93% to 43%).
#
# The reason been that the state has replaced the ACT which was offered to students free of charge for the past 15 years (https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html) with the state funded SAT in 2016 and making it mandatory (https://www.testive.com/illinois/).
#
# #### Colorado
#
# There is also a drastic jump in SAT participation rate of 89% (from 11% to 100%) from 2017 to 2018, with corresponding fall in ACT participation rate of 70% (from 100% to 30%).
#
# Similar to Illinois, the mandatory state administered ACT was replaced by the SAT in 2017 which prompted the significant jump in SAT participation rate in 2018 (https://www.denverpost.com/2017/03/06/colorado-juniors-sat-college-exam/).
#
# #### Ohio
#
# There is a moderate increase in SAT participation rate of 6% (from 12 to 18%) and ACT participation rate of 25% (75% to 100%) from 2017 to 2018. This is a result of a state law passed in 2017 which requires all districts and schools to administer SAT or ACT tests to juniors, with more than 95% of the districts choosing ACT over SAT (https://www.cleveland.com/metro/2018/10/more_ohio_students_took_the_ac.html).

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Based on the analysis above, the key takeaways are:
#
# - The participation rates for SAT and ACT are highly influenced by the state policies on college admissions. The participation rate for a particular test would increase exponentially if a state were to administer mandatory adoption of SAT/ ACT or fully subsidised the test fees for high school graduates, with corresponding fall in the participation rate of the other test as most colleges in United States only require students to take one test to assess readiness for college admission.
#
# - SAT and ACT Participation rates are negatively correlated with test scores; high participation rates for either tests would likely mean lower test scores.
#
# It is recommended that efforts to increase participation rates for SAT should be targeted towards California state based on the grounds below:
#
# - There is currently no mandatory requirement to administer ACT for college admissions.
# - SAT is currently a more popular assessment for college bound juniors to take in most districts within California with state participation rates more than two times that of ACT. Hence there would be better chances of success in convincing the colleges to adopt SAT as the testing standard.
# - High student population base thus resources could be allocated more efficiently to maximise pay-offs in increasing participation rate.
#
# Suggestions the College Board could adopt to increase SAT participation rate include:
#
# - Reducing or fully subsidise SAT fees making them more price competitive and accessible to lower income students.
# - Making preparatory resources readily available and combining with free tutoring classes which have added advantage to raise test scores.
# - Working closely with high schools and colleges to convince them the the merits of the SAT in testing students'knowledge of the common core
#
# Lastly, additional data that would help better inform investigations include:
#
# - more granular data by districts
# - admission criteria cut-off scores by state and district
# - composition of students taking the tests e.g. race, income level, etc.
